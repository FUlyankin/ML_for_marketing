# %% [markdown]
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/cats.jpg" height="1200" width="1200">
#
# # <center> ML для маркетинга. <br>  <br> Групповая домашка: Тематическое моделирование </center>
#
# (придумать клёвую аббревиатуру для этого)

# %% [markdown]
# В этой домашке вам предстоит с нуля сделать своё небольшое исследование. Надо будет скачать данные, обработать их, построить модель, описать результаты, а ещё всё это в команде. Короче говоря, ужас полный!
#
# ##  Постановка задачи
#
# Наша цель выбрать какие-нибудь интересные аудитории и проанализировать каким именно контентом они интересуются. На основе их интересов нужно попробовать нарисовать профили пользователей. Работа будет состоять из трёх частей:
#
# ### Часть 1:  сбор данных
#
# Нужно понять какие именно аудитории вы собираетесь проанализировать и что именно вам для этого хотелось бы скачать из вконтакте. Ну и, конечно же, после это нужно скачать.
#
# __Пример 1:__ хммм... интересно что именно пишут у себя на стенках подписчики разных групп с мемами. Можно ли на основе их постов на стенках построить типичный портрет подпичика абстрактных мемов и посмотреть чем именно в плане своих интересов отличается от подписчиков других пабликов?
#
# __Пример 2:__ хммм... музыка это тааааак клёво. Интересно, что пишут фанаты в музыкальных пабликах разных жанров. Они обсуждают одно и то же или что-то разное? Насколько близки фанаты Баскова к фанатам Тимати по своим обсуждениям? Какие жанры похожи, а какие очень далеки друг от друга. Можно ли разбить всю музыку на новые жанры по ... комментаторам?
#
# Вам нужно придумать свою задачку и скачать под неё данные. Чётко сформулируйте вопрос, который вы задаёте себе в вашем исследовании.
#
# __Важно:__  на метод `wall.get` есть ограничение! Можно скачивать не более $5000$ стен в сутки. Когда вы пробьёте его, вы увидете ошибку
#
# ```
# {'error': {'error_code': 29,
#   'error_msg': 'Rate limit reached',
#   'request_params': [{'key': 'owner_id', 'value': '43152073'},
#    {'key': 'count', 'value': '100'},
#    {'key': 'v', 'value': '5.103'},
#    {'key': 'method', 'value': 'wall.get'},
#    {'key': 'oauth', 'value': '1'}]}}
# ```
#
# Нужно будет сделать в скачке перерыв. Скачивайте данные без фанатизма. Если вы выбрали $5$ пабликов и с каждого из них скачали по $2000$ человек, этого более чем достаточно! Более того, не забывайте, что домашка командная. В каждой команде есть три человека. Это сделано не для того, чтобы один человек всё скачал, а остальные получили оценку. Это сделано, чтобы вы могли качать данные параллельно, а потом скрепить их в один общий большой датасет. __Если вы скачаете мало данных, за этот пункт вы получите мало баллов.__  Лучше всего сохранять скаченные паблики в разные файлы.
#
#
# ### Часть 2: тематическая модель
#
# Нужно построить тематическую модель, проинтерпретировать её, построить для всех людей и групп тематические профили.
#
#
# ### Часть 3: визуализация и интерпретация
#
# Нужно построить кучу картинок, всё проинтерпретировать и сделать какой-то глубокий вывод о разных аудиториях.
#
#
# #### Оценивание:
#
# Мы будем оценивать три составляющие:
#
# -  __[7 баллов]__ Насколько осмысленно вы скачивали данные. Если вы скачиваете что-то интересное, а после используете это в анализе, мы щедро поощрим это дополнительными баллами.
# - __[6 баллов]__ Вы построили модель и проинтерпретировали тематики.
# - __[7 баллов]__ Анализ и интерпретация тех результатов, которые вы получили при моделировании.
#
# __Задание сдаётся в Anytask. Дедлайн: 23:30 18 декабря.__
#
#
# ### Полезные материалы
#
# * [Тетрадка с семинара по API вконтакте](https://nbviewer.jupyter.org/github/FUlyankin/HSE_Data_Culture/blob/master/ML_for_marketing_2019/sems/sem10_vk/vk_parser_full.ipynb)
# * [Расширенная тетрадка по мотивам семинара,](https://nbviewer.jupyter.org/github/FUlyankin/HSE_Data_Culture/blob/master/ML_for_marketing_2019/sems/sem10_vk/vk_parser_download.ipynb)  которой я скачивал мемы
# * [Туториал по тому как качать вконтакте,](https://nbviewer.jupyter.org/github/FUlyankin/ekanam_grand_research/blob/master/0.%20vk_parser_tutorial.ipynb) в нём есть функция, которая ускоряет скачку в 25 раз. Она обычно довольно полезна для скачки лайков и комментариев.
#
# * [Небольшой проект от меня и моего Димы](https://github.com/DmitrySerg/top-russian-music) про рэпчик и тематическое моделирование
# * [Дима рассказывает про этот проект на PyData](https://www.youtube.com/watch?v=MEBjnGaHsmw)  (видос полчаса без регистрации и смс)
